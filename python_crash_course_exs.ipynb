# %% [markdown]
# # Chapter 2

# %%
# STRINGS
# 2-3
message = "Hello Eric!"
print(message)

# 2-4
name = "Teo"
print(f"Hello, {name.upper()}!")
print(f"Hello, {name.lower()}!")
print(f"Hello, {name.title()}!")

# 2-5
quote = 'Albert Einstein once said, "A person who never made a mistake never tried anything new."'
print(quote)

# 2-6
famous_person = "Albert Einstein"
message = f'{famous_person} once said, "A person who never made a mistake never tried anything new."'
print(message)

# 2-7
name = "\t  Teo\n  "
print(name)
print(name.lstrip())
print(name.rstrip())
print(name.strip())

# 2-8
filename = "python_notes.txt"
print(f"{filename.removesuffix('.txt')}")
# Out:
# Hello Eric!
# Hello, TEO!
# Hello, teo!
# Hello, Teo!
# Albert Einstein once said, "A person who never made a mistake never tried anything new."
# Albert Einstein once said, "A person who never made a mistake never tried anything new."
# 	  Teo
#
# Teo
#
# 	  Teo
# Teo
# python_notes

# %%
# NUMBERS
# 2-9
print(5 + 3)
print(10 - 2)
print(4 * 2)
print(int(16 / 2))

# 2-10
favorite_number = 67
print(f"My favorite number is {favorite_number}.")
# Out:
# 8
# 8
# 8
# 8
# My favorite number is 67.

# %% [markdown]
# # Chapter 3

# %%
# 3-1, 3-2
names = ["facu", "joaco", "fran"]
for name in names:
    print(f"Hello, {name.title()}!")

# 3-3
transportation = ["car", "motorcycle", "bicycle"]
for item in transportation:
    print(f"I would like to own a {item}.")
# Out:
# Hello, Facu!
# Hello, Joaco!
# Hello, Fran!
# I would like to own a car.
# I would like to own a motorcycle.
# I would like to own a bicycle.

# %% [markdown]
# # Chapter 9: Classes

# %%
#9-1
class Restaurant:
    """A class representing a restaurant."""

    def __init__(self, name, cuisine_type):
      """Initialize the restaurant."""
      self.name = name
      self.cuisine_type = cuisine_type

    def describe_restaurant(self):
      print(f"The name of the restaurant is {self.name}")
      print(f"The cuisine type of the restaurant is {self.cuisine_type}")

    def open_restaurant(self):
      print(f"{self.name} is open")

# %%
restaurant = Restaurant("Asato", "Sushi")

print(restaurant.name)
print(restaurant.cuisine_type)

restaurant.describe_restaurant()
restaurant.open_restaurant()
# Out:
# Asato
# Sushi
# The name of the restaurant is Asato
# The cuisine type of the restaurant is Sushi
# Asato is now open!

# %%
#9-2
restaurant1 = Restaurant("KFC", "Fast Food")

restaurant1.describe_restaurant()

restaurant2 = Restaurant("McDonalds", "Fast Food")

restaurant2.describe_restaurant()

restaurant3 = Restaurant("Kentucky", "Pizza")

restaurant3.describe_restaurant()
# Out:
# The name of the restaurant is KFC
# The cuisine type of the restaurant is Fast Food
# The name of the restaurant is McDonalds
# The cuisine type of the restaurant is Fast Food
# The name of the restaurant is Kentucky
# The cuisine type of the restaurant is Pizza

# %%
#9-3
class User:
  """A class representing a user."""

  def __init__(self, first_name, last_name, phone_number, email, country):
    """Initialize the user."""
    self.first_name = first_name
    self.last_name = last_name
    self.phone_number = phone_number
    self.email = email
    self.country = country

  def describe_user(self):
    """Describe the user"""
    print(f"User summary:\n"
      f"First name: {self.first_name}, Last name: {self.last_name}\n"
      f"Phone number: {self.phone_number}\n"
      f"Email: {self.email}\n"
      f"Country: {self.country}")

  def greet_user(self):
    """Greet the user"""
    print(f"Greetings, {self.first_name} {self.last_name} from {self.country}!")

# %%
user1 = User("Teo", "Spring", 123, "teo@gmail.com", "Argentina")

user1.describe_user()
user1.greet_user()

user2 = User("Juan", "Perez", 321, "juanperez@outlook.com", "Colombia")

user2.describe_user()
user2.greet_user()

user3 = User("Marta", "Sanchez", 890, "marta_s@gmail.com.ar", "Argentina")

user3.describe_user()
user3.greet_user()
# Out:
# User summary:
# First name: Teo, Last name: Spring
# Phone number: 123
# Email: teo@gmail.com
# Country: Argentina
# Greetings, Teo Spring from Argentina!
# User summary:
# First name: Juan, Last name: Perez
# Phone number: 321
# Email: juanperez@outlook.com
# Country: Colombia
# Greetings, Juan Perez from Colombia!
# User summary:
# First name: Marta, Last name: Sanchez
# Phone number: 890
# Email: marta_s@gmail.com.ar
# Country: Argentina
# Greetings, Marta Sanchez from Argentina!

# %%
#9-4
class Restaurant:
    """A class representing a restaurant."""

    def __init__(self, name, cuisine_type):
      """Initialize the restaurant."""
      self.name = name
      self.cuisine_type = cuisine_type
      self.number_served = 0

    def describe_restaurant(self):
      print(f"The name of the restaurant is {self.name}")
      print(f"The cuisine type of the restaurant is {self.cuisine_type}")
      print(f"The number of customers served is {self.number_served}")

    def open_restaurant(self):
      print(f"{self.name} is open")

    def set_number_served(self, served):
      self.number_served = served

    def increment_number_served(self, customers):
      self.number_served += customers

# %%
restaurant = Restaurant ("Venice", "Bar")

restaurant.describe_restaurant()

restaurant.number_served = 10

restaurant.describe_restaurant()

restaurant.set_number_served(30)

restaurant.describe_restaurant()

restaurant.increment_number_served(30)

restaurant.describe_restaurant()
# Out:
# The name of the restaurant is Venice
# The cuisine type of the restaurant is Bar
# The number of customers served is 0
# The name of the restaurant is Venice
# The cuisine type of the restaurant is Bar
# The number of customers served is 10
# The name of the restaurant is Venice
# The cuisine type of the restaurant is Bar
# The number of customers served is 30
# The name of the restaurant is Venice
# The cuisine type of the restaurant is Bar
# The number of customers served is 60

# %%
#9-5
class User:
  """A class representing a user."""

  def __init__(self, first_name, last_name, phone_number, email, country):
    """Initialize the user."""
    self.first_name = first_name
    self.last_name = last_name
    self.phone_number = phone_number
    self.email = email
    self.country = country
    self.login_attempts = 0

  def describe_user(self):
    """Describe the user"""
    print(f"User summary:\n"
      f"First name: {self.first_name}, Last name: {self.last_name}\n"
      f"Phone number: {self.phone_number}\n"
      f"Email: {self.email}\n"
      f"Country: {self.country}")

  def greet_user(self):
    """Greet the user"""
    print(f"Greetings, {self.first_name} {self.last_name} from {self.country}!")

  def increment_login_attempts(self):
    self.login_attempts += 1

  def reset_login_attempts(self):
    self.login_attempts = 0

# %%
user = User("Teo", "Spring", 123, "teo@gmail.com", "Argentina")

# %%
user.increment_login_attempts()
print(user.login_attempts)
# Out:
# 10

# %%
user.reset_login_attempts()
print(user.login_attempts)
# Out:
# 0
